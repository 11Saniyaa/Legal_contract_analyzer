# %%
from dotenv import load_dotenv
load_dotenv()

import os, json, hashlib
import fitz
from groq import Groq
from neo4j import GraphDatabase

from langgraph.graph import StateGraph, END
from typing import TypedDict, List, Dict, Any

from sentence_transformers import SentenceTransformer
import numpy as np

# %%
# ===== IMPROVED: Configuration and Constants =====
import os
from typing import Optional

# Embedding configuration
EMBEDDING_DIM = 384  # Standardized dimension for all-MiniLM-L6-v2
HF_EMBED_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
MAX_TEXT_CHUNK = 8000  # Max characters per chunk
CHUNK_OVERLAP = 500    # Overlap between chunks

# API Configuration
GROQ_MODEL = "llama-3.1-8b-instant"
MAX_TOKENS = 8000
TEMPERATURE = 0.1

# Retry configuration
MAX_RETRIES = 3
RETRY_DELAY = 1  # seconds

def validate_env_vars():
    """Validate required environment variables"""
    required = ['GROQ_API_KEY', 'HF_TOKEN', 'NEO4J_URI', 'NEO4J_USERNAME', 'NEO4J_PASSWORD']
    missing = [var for var in required if not os.getenv(var)]
    if missing:
        raise ValueError(f"Missing required environment variables: {', '.join(missing)}")
    return True

# Validate on import
try:
    validate_env_vars()
    print("✅ Environment variables validated")
except ValueError as e:
    print(f"⚠️ {e}")
# Out:
# ✅ Environment variables validated

# %%
# ===== IMPROVED: Retry Logic with Exponential Backoff =====
import time
from functools import wraps

def retry_with_backoff(max_retries=MAX_RETRIES, delay=RETRY_DELAY, backoff=2):
    """Decorator for retrying functions with exponential backoff"""
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            retries = 0
            current_delay = delay
            while retries < max_retries:
                try:
                    return func(*args, **kwargs)
                except Exception as e:
                    retries += 1
                    if retries >= max_retries:
                        print(f"❌ {func.__name__} failed after {max_retries} retries: {str(e)}")
                        raise
                    print(f"⚠️ {func.__name__} failed (attempt {retries}/{max_retries}), retrying in {current_delay}s...")
                    time.sleep(current_delay)
                    current_delay *= backoff
            return None
        return wrapper
    return decorator

print("✅ Retry utility loaded")
# Out:
# ✅ Retry utility loaded

# %%
# ===== IMPROVED: Text Chunking for Large Contracts =====
def chunk_text(text: str, max_size: int = MAX_TEXT_CHUNK, overlap: int = CHUNK_OVERLAP) -> list:
    """
    Split large text into overlapping chunks for processing.
    
    Args:
        text: Input text to chunk
        max_size: Maximum characters per chunk
        overlap: Number of characters to overlap between chunks
    
    Returns:
        List of text chunks
    """
    if len(text) <= max_size:
        return [text]
    
    chunks = []
    start = 0
    
    while start < len(text):
        end = start + max_size
        chunk = text[start:end]
        chunks.append(chunk)
        
        # Move start position with overlap
        start = end - overlap
        if start >= len(text):
            break
    
    return chunks

def merge_chunk_analyses(chunk_results: list) -> dict:
    """
    Merge analysis results from multiple chunks into a single result.
    
    Args:
        chunk_results: List of analysis dictionaries from chunks
    
    Returns:
        Merged analysis dictionary
    """
    if not chunk_results:
        return {}
    
    merged = {
        "title": chunk_results[0].get("title", ""),
        "parties": [],
        "dates": [],
        "governing_law": chunk_results[0].get("governing_law", ""),
        "clauses": []
    }
    
    # Collect unique parties
    seen_parties = set()
    for result in chunk_results:
        for party in result.get("parties", []):
            party_key = str(party.get("name", "")) + str(party.get("role", ""))
            if party_key not in seen_parties:
                merged["parties"].append(party)
                seen_parties.add(party_key)
    
    # Collect unique dates
    seen_dates = set()
    for result in chunk_results:
        for date in result.get("dates", []):
            date_key = str(date.get("value", "")) + str(date.get("type", ""))
            if date_key not in seen_dates:
                merged["dates"].append(date)
                seen_dates.add(date_key)
    
    # Collect all clauses
    seen_clauses = set()
    for result in chunk_results:
        for clause in result.get("clauses", []):
            clause_key = clause.get("clause_name", "")
            if clause_key and clause_key not in seen_clauses:
                merged["clauses"].append(clause)
                seen_clauses.add(clause_key)
    
    return merged

print("✅ Chunking utilities loaded")
# Out:
# ✅ Chunking utilities loaded

# %%
# ===== IMPROVED: Enhanced Embedding Function with Retry =====
@retry_with_backoff(max_retries=MAX_RETRIES)
def get_embeddings_api_improved(text: str) -> Optional[list]:
    """
    Get embeddings using HuggingFace Inference API with improved error handling.
    
    Args:
        text: Text to generate embeddings for
    
    Returns:
        List of floats (384 dimensions) or None if failed
    """
    if not text or not text.strip():
        return None
    
    headers = {
        "Authorization": f"Bearer {os.getenv('HF_TOKEN')}",
        "Content-Type": "application/json"
    }
    
    payload = {
        "inputs": text[:MAX_TEXT_CHUNK],  # Limit input size
        "options": {"wait_for_model": True}
    }
    
    try:
        response = requests.post(
            f"https://router.huggingface.co/hf-inference/models/{HF_EMBED_MODEL}",
            headers=headers,
            json=payload,
            timeout=30
        )
        
        if response.status_code == 200:
            result = response.json()
            
            # Handle nested list response (token embeddings)
            if isinstance(result, list) and len(result) > 0:
                if isinstance(result[0], list):
                    # Mean pool token embeddings
                    import numpy as np
                    emb = np.mean(result, axis=0).tolist()
                else:
                    emb = result
            else:
                emb = result
            
            # Validate dimension
            if isinstance(emb, list) and len(emb) == EMBEDDING_DIM:
                return emb
            elif isinstance(emb, list) and len(emb) > 0:
                # Truncate or pad to correct dimension
                if len(emb) > EMBEDDING_DIM:
                    return emb[:EMBEDDING_DIM]
                else:
                    return emb + [0.0] * (EMBEDDING_DIM - len(emb))
            else:
                return None
        else:
            print(f"⚠️ HF API returned status {response.status_code}")
            return None
            
    except requests.exceptions.Timeout:
        print("⚠️ HF API request timed out")
        return None
    except Exception as e:
        print(f"⚠️ HF API error: {str(e)}")
        return None

def validate_embedding(emb: Optional[list], expected_dim: int = EMBEDDING_DIM) -> list:
    """
    Validate and fix embedding dimensions.
    
    Args:
        emb: Embedding vector or None
        expected_dim: Expected dimension (default 384)
    
    Returns:
        Valid embedding vector of correct dimension
    """
    if emb is None or not isinstance(emb, list):
        return [0.0] * expected_dim
    
    if len(emb) == expected_dim:
        return emb
    elif len(emb) > expected_dim:
        return emb[:expected_dim]
    else:
        return emb + [0.0] * (expected_dim - len(emb))

print("✅ Improved embedding functions loaded")
# Out:
# ✅ Improved embedding functions loaded

# %%
# ===== IMPROVED: Enhanced JSON Parsing with Better Error Recovery =====
import re
import json

def parse_llm_json(content: str, max_attempts: int = 3) -> Optional[dict]:
    """
    Parse JSON from LLM output with multiple fallback strategies.
    
    Args:
        content: Raw LLM output string
        max_attempts: Maximum parsing attempts
    
    Returns:
        Parsed dictionary or None
    """
    if not content:
        return None
    
    # Strategy 1: Direct JSON parse
    try:
        return json.loads(content)
    except json.JSONDecodeError:
        pass
    
    # Strategy 2: Remove markdown code blocks
    cleaned = content
    if "```json" in cleaned:
        cleaned = cleaned.split("```json")[1].split("```")[0].strip()
    elif "```" in cleaned:
        cleaned = cleaned.split("```")[1].split("```")[0].strip()
    
    try:
        return json.loads(cleaned)
    except json.JSONDecodeError:
        pass
    
    # Strategy 3: Extract JSON object boundaries
    if "{" in cleaned and "}" in cleaned:
        start = cleaned.find("{")
        end = cleaned.rfind("}") + 1
        json_str = cleaned[start:end]
        
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            pass
    
    # Strategy 4: Fix common JSON issues
    try:
        # Fix unescaped quotes in strings
        fixed = re.sub(r'(?<!\\)"(?=\w)', r'\\"', cleaned)
        # Remove trailing commas
        fixed = re.sub(r',\s*}', '}', fixed)
        fixed = re.sub(r',\s*]', ']', fixed)
        
        return json.loads(fixed)
    except json.JSONDecodeError as e:
        print(f"⚠️ JSON parsing failed after all attempts: {e}")
        return None

def validate_analysis_data(data: dict) -> dict:
    """
    Validate and fix analysis data structure.
    
    Args:
        data: Analysis dictionary from LLM
    
    Returns:
        Validated and fixed analysis dictionary
    """
    if not isinstance(data, dict):
        return {
            "title": "Unknown Contract",
            "parties": [],
            "dates": [],
            "governing_law": "Not Specified",
            "clauses": []
        }
    
    # Ensure required fields exist
    validated = {
        "title": data.get("title", "Unknown Contract"),
        "parties": data.get("parties", []),
        "dates": data.get("dates", []),
        "governing_law": data.get("governing_law", "Not Specified"),
        "clauses": data.get("clauses", [])
    }
    
    # Validate clauses
    validated_clauses = []
    for clause in validated["clauses"]:
        if isinstance(clause, dict):
            validated_clause = {
                "clause_name": clause.get("clause_name", "Unnamed Clause"),
                "summary": clause.get("summary", ""),
                "risk_level": clause.get("risk_level", "MEDIUM"),
                "risk_reason": clause.get("risk_reason", ""),
                "obligation": clause.get("obligation", ""),
                "liability": clause.get("liability", ""),
                "ai_summary": clause.get("ai_summary", "")
            }
            # Ensure risk_level is valid
            if validated_clause["risk_level"] not in ["LOW", "MEDIUM", "HIGH"]:
                validated_clause["risk_level"] = "MEDIUM"
            validated_clauses.append(validated_clause)
    
    validated["clauses"] = validated_clauses
    return validated

print("✅ Improved JSON parsing utilities loaded")
# Out:
# ✅ Improved JSON parsing utilities loaded

# %%
# ===== HF EMBEDDING VIA API (NO MODEL DOWNLOAD) =====
import requests

HF_TOKEN = os.environ.get("HF_TOKEN")
HF_EMBED_MODEL = "sentence-transformers/all-MiniLM-L6-v2"  # Reliable model
HF_API_URL = (
    f"https://router.huggingface.co/hf-inference/models/{HF_EMBED_MODEL}"
)
# Groq
groq_client = Groq(api_key=os.environ["GROQ_API_KEY"])

# Neo4j - Auto-fix Aura URI for SSL compatibility
uri = os.environ["NEO4J_URI"]

# Fix for Neo4j Aura: convert neo4j+s:// to neo4j+ssc:// (uses system cert store)
if "neo4j+s://" in uri and "neo4j+ssc://" not in uri:
    uri = uri.replace("neo4j+s://", "neo4j+ssc://")
    print(f"🔄 Updated URI for Aura compatibility: {uri[:50]}...")

neo4j_driver = GraphDatabase.driver(
    uri,
    auth=(os.environ["NEO4J_USERNAME"], os.environ["NEO4J_PASSWORD"])
)

# Test connection
try:
    neo4j_driver.verify_connectivity()
    print("✅ Neo4j Aura connection successful!")
except Exception as e:
    print(f"❌ Neo4j connection failed: {e}")
    print("💡 Make sure:")
    print("   1. Your NEO4J_URI uses neo4j+ssc:// or neo4j+s://")
    print("   2. Username and password are correct")
    print("   3. Your Aura database is running")
    raise

def get_embeddings_api(text):
    """Get embeddings using HuggingFace Inference API"""
    headers = {"Authorization": f"Bearer {HF_TOKEN}"}
    payload = {"inputs": text, "options": {"wait_for_model": True}}
    
    try:
        response = requests.post(HF_API_URL, headers=headers, json=payload, timeout=2)
        
        if response.status_code == 200:
            result = response.json()
            # Handle different response formats
            if isinstance(result, list):
                if isinstance(result[0], list):
                    return result[0]  # Nested list
                return result
            return result
        else:
            # print(f"❌ API Error: {response.status_code} - {response.text}")
            return None
    except Exception as e:
        print(f"❌ Exception: {str(e)}")
        return None

print("✅ Clients initialized (API mode - no model download)")
# Out:
# 🔄 Updated URI for Aura compatibility: neo4j+ssc://8c5998b9.databases.neo4j.io...
# ✅ Neo4j Aura connection successful!
# ✅ Clients initialized (API mode - no model download)

# %%
def pdf_hash(path):
    with open(path, "rb") as f:
        return hashlib.sha256(f.read()).hexdigest()

def extract_text(pdf):
    doc = fitz.open(pdf)
    return "".join(p.get_text() for p in doc)

def safe_str(v):
    return v.strip() if isinstance(v, str) else None

def normalize_list(items, key=None):
    out = []
    for i in items:
        if isinstance(i, dict):
            val = i.get(key) if key else None
            if val:
                out.append(val)
        elif isinstance(i, str):
            out.append(i)
    return out

# %%
def print_contract_summary(data):
    """Enhanced summary printer with all details"""
    print("\n" + "="*80)
    print("📄 CONTRACT SUMMARY")
    print("="*80)

    print(f"\n📌 BASIC INFORMATION")
    print("-"*80)
    print(f"Title          : {data.get('title', 'N/A')}")
    print(f"File Name      : {data.get('file_name', 'N/A')}")
    print(f"Contract ID    : {data.get('contract_id', 'N/A')}")
    print(f"Governing Law  : {data.get('governing_law', 'N/A')}")

    # Parties
    print(f"\n👥 PARTIES ({len(data.get('parties', []))})")
    print("-"*80)
    for i, p in enumerate(data.get('parties', []), 1):
        print(f"  [{i}] {p}")

    # Important Dates
    print(f"\n📅 IMPORTANT DATES ({len(data.get('dates', []))})")
    print("-"*80)
    for i, d in enumerate(data.get('dates', []), 1):
        print(f"  [{i}] {d}")

    # Clauses with Risk Analysis
    print(f"\n⚖️ CLAUSE RISK ANALYSIS ({len(data.get('clauses', []))})")
    print("="*80)
    for i, c in enumerate(data.get("clauses", []), 1):
        print(f"\n[Clause {i}] {c.get('clause_name', 'Unnamed')}")
        print("-"*80)
        print(f"Summary      : {c.get('summary', 'N/A')}")
        print(f"\n🚨 Risk Level : {c.get('risk_level', 'N/A')}")
        print(f"Risk Reason  : {c.get('risk_reason', 'N/A')}")
        print(f"\n📋 Obligation : {c.get('obligation', 'N/A')}")
        print(f"💼 Liability  : {c.get('liability', 'N/A')}")
        print(f"\n🤖 AI Summary : {c.get('ai_summary', 'N/A')}")
        print("-"*80)
    
    print("\n" + "="*80)

# %%
class ContractState(TypedDict):
    pdf_path: str
    cid: str
    text: str
    embeddings: List[float]
    analysis: Dict[str, Any]

# %%
def pdf_extraction_agent(state: ContractState):
    print(f"\n📄 Extracting PDF: {state['pdf_path']}")
    text = extract_text(state["pdf_path"])
    return {
        **state,
        "text": text
    }

# %%
def embedding_agent(state: ContractState):
    print("🔢 Generating embeddings via HuggingFace API")

    # Limit chunk size for HF inference safety
    text_chunk = state["text"][:8000]

    emb = get_embeddings_api(text_chunk)

    # Fallback if API fails or returns bad data
    if (
        emb is None
        or not isinstance(emb, list)
        or len(emb) == 0
    ):
        print("⚠️ Using fallback embeddings")
        emb = [0.0] * 384  # all-MiniLM-L6-v2 → 384 dims

    # Handle nested response ([[...]])
    if isinstance(emb[0], list):
        emb = emb[0]

    # Final dimension guard (VERY important for Neo4j vector index)
    if len(emb) != 384:
        print(f"⚠️ Invalid embedding size {len(emb)}, forcing fallback")
        emb = [0.0] * 384

    print(f"   Embedding dimension: {len(emb)}")

    return {
        **state,
        "embeddings": emb
    }
def get_embeddings_api(text):
    headers = {
        "Authorization": f"Bearer {HF_TOKEN}",
        "Content-Type": "application/json"
    }

    payload = {
        "inputs": text,
        "options": {
            "wait_for_model": True
        }
    }

    try:
        response = requests.post(
            HF_API_URL,
            headers=headers,
            json=payload,
            timeout=30
        )

        if response.status_code == 200:
            result = response.json()

            # HF returns: [ [token_embeddings...] ]
            # We must MEAN POOL
            if isinstance(result, list) and isinstance(result[0], list):
                import numpy as np
                return np.mean(result, axis=0).tolist()

            print("⚠️ Unexpected HF response:", result)
            return None

        else:
            # print(f"❌ API Error: {response.status_code} - {response.text}")
            return None

    except Exception as e:
        print(f"❌ Exception: {e}")
        return None

# %%
# def get_embeddings_api(text):
#     headers = {
#         "Authorization": f"Bearer {HF_TOKEN}",
#         "Content-Type": "application/json"
#     }

#     payload = {
#         "inputs": text,
#         "options": {"wait_for_model": True}
#     }

#     try:
#         response = requests.post(
#             HF_API_URL,
#             headers=headers,
#             json=payload,
#             timeout=30
#         )

#         if response.status_code == 200:
#             result = response.json()

#             # token-level embeddings → mean pooling
#             if isinstance(result, list) and isinstance(result[0], list):
#                 import numpy as np
#                 return np.mean(result, axis=0).tolist()

#             print("⚠️ Unexpected HF response:", result)
#             return None

#         print(f"❌ HF API Error {response.status_code}: {response.text}")
#         return None

#     except Exception as e:
#         print(f"❌ HF Exception: {e}")
#         return None

# %%
def analysis_agent(state: ContractState):
    print("🧠 Analyzing contract via Groq LLM")

    # Enhanced prompt for better extraction
    prompt = f"""
You are a legal contract analyzer. Analyze the following contract and extract detailed information.

CRITICAL: Return ONLY valid JSON. No markdown, no explanations, just the JSON object.

{{
  "title": "Contract title",
  "parties": [
    {{"name": "Party 1 name", "role": "Role (e.g., Service Provider, Client)"}},
    {{"name": "Party 2 name", "role": "Role"}}
  ],
  "dates": [
    {{"type": "Effective Date", "value": "YYYY-MM-DD or as mentioned"}},
    {{"type": "Expiration Date", "value": "YYYY-MM-DD or as mentioned"}}
  ],
  "governing_law": "Jurisdiction and governing law",
  "clauses": [
    {{
      "clause_name": "Name of the clause",
      "summary": "Brief summary of what this clause says",
      "risk_level": "Low/Medium/High",
      "risk_reason": "Detailed explanation of why this risk level was assigned. Mention specific concerns, potential liabilities, or unfavorable terms.",
      "obligation": "Specific obligations this clause imposes on parties. Be detailed.",
      "liability": "What liabilities or penalties are mentioned in this clause. Include financial limits if any.",
      "ai_summary": "A comprehensive AI analysis of this clause including: 1) What it means in plain language, 2) Key takeaways, 3) Red flags or concerns, 4) Recommendations"
    }}
  ]
}}

IMPORTANT INSTRUCTIONS:
1. Extract ALL major clauses from the contract (aim for 5-10 clauses)
2. For risk_reason: Explain WHY you assigned that risk level with specific concerns
3. For ai_summary: Provide detailed analysis (at least 2-3 sentences)
4. Be thorough - don't leave fields empty
5. Focus on: payment terms, termination, liability, intellectual property, confidentiality, warranties, indemnification
6. ESCAPE all quotes inside strings properly using backslash
7. Do NOT include any text before or after the JSON object

CONTRACT TEXT:
{state["text"][:10000]}
"""

    try:
        res = groq_client.chat.completions.create(
            model="llama-3.1-8b-instant",
            messages=[
                {"role": "system", "content": "You are a JSON-only API. Return only valid JSON, no markdown or explanations."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.1,
            max_tokens=8000
        )

        content = res.choices[0].message.content.strip()
        
        # Clean the response
        # Remove markdown code blocks
        if "```json" in content:
            content = content.split("```json")[1].split("```")[0].strip()
        elif "```" in content:
            content = content.split("```")[1].split("```")[0].strip()
        
        # Remove any leading/trailing whitespace
        content = content.strip()
        
        # Try to find JSON object boundaries
        if not content.startswith("{"):
            start = content.find("{")
            if start != -1:
                content = content[start:]
        
        if not content.endswith("}"):
            end = content.rfind("}")
            if end != -1:
                content = content[:end+1]
        
        # Attempt to parse
        try:
            analysis = json.loads(content)
        except json.JSONDecodeError as e:
            print(f"⚠️ JSON parsing failed at position {e.pos}: {e.msg}")
            print(f"Problematic content around error: ...{content[max(0,e.pos-50):e.pos+50]}...")
            
            # Try to fix common issues
            import re
            
            # Fix unescaped quotes in strings
            content = re.sub(r'(?<!\\)"(?=\w)', r'\\"', content)
            
            # Try parsing again
            try:
                analysis = json.loads(content)
                print("✅ JSON fixed and parsed successfully")
            except:
                print("❌ Could not fix JSON, using fallback structure")
                # Fallback structure
                analysis = {
                    "title": "Contract Analysis",
                    "parties": [{"name": "Party A", "role": "Unknown"}, {"name": "Party B", "role": "Unknown"}],
                    "dates": [{"type": "Effective Date", "value": "Not specified"}],
                    "governing_law": "Not specified",
                    "clauses": [
                        {
                            "clause_name": "General Terms",
                            "summary": "Contract terms extracted from document",
                            "risk_level": "Medium",
                            "risk_reason": "Unable to fully analyze due to parsing error. Manual review recommended.",
                            "obligation": "Review document manually for obligations",
                            "liability": "Review document manually for liabilities",
                            "ai_summary": "Automated analysis encountered an error. This contract requires manual legal review to identify all terms, conditions, and potential risks."
                        }
                    ]
                }
        
        print(f"✅ Analysis complete - Found {len(analysis.get('clauses', []))} clauses")

        return {
            **state,
            "analysis": analysis
        }
        
    except Exception as e:
        print(f"❌ Analysis error: {str(e)}")
        # Return minimal fallback
        return {
            **state,
            "analysis": {
                "title": "Error in Analysis",
                "parties": [],
                "dates": [],
                "governing_law": "Unknown",
                "clauses": []
            }
        }

# %%
def store_graph_agent(state: ContractState):
    data = state["analysis"]
    cid = state["cid"]
    filename = os.path.basename(state["pdf_path"])
    embeddings = state["embeddings"]

    print("🗄️ Storing into Neo4j with vector embeddings")

    with neo4j_driver.session() as s:

        # Contract with embeddings
        s.run("""
        MERGE (c:Contract {id:$id})
        SET c.title=$title,
            c.file_name=$file,
            c.governing_law=$law,
            c.embedding=$emb
        """, id=cid, title=data.get("title", "Unknown Contract"), file=filename, 
             law = data.get("governing_law", "Not Specified"), emb=embeddings)

        # Parties with roles
        for p in data.get("parties", []):
            if isinstance(p, dict):
                s.run("""
                MERGE (o:Organization {name:$name})
                SET o.role=$role
                WITH o
                MATCH (c:Contract {id:$id})
                MERGE (o)-[:IS_PARTY_TO]->(c)
                """, name=p.get("name"), role=p.get("role"), id=cid)

        # Dates with types
        for d in data.get("dates", []):
            if isinstance(d, dict):
                s.run("""
                MERGE (dt:ImportantDate {value:$v})
                SET dt.type=$type
                WITH dt
                MATCH (c:Contract {id:$id})
                MERGE (c)-[:HAS_DATE]->(dt)
                """, v=d.get("value"), type=d.get("type"), id=cid)

        # Clauses with all details
        for cl in data.get("clauses", []):
            # Generate embedding for each clause via API
            clause_text = f"{cl.get('clause_name', '')} {cl.get('summary', '')}"
            clause_emb = get_embeddings_api(clause_text)
            
            if clause_emb is None:
                clause_emb = [0.0] * 384  # Fixed: Use 384 to match all-MiniLM-L6-v2 model
            
            # Normalize if nested
            if isinstance(clause_emb[0], list):
                clause_emb = clause_emb[0]
            
            s.run("""
            MATCH (c:Contract {id:$id})
            CREATE (cl:Clause {
                name:$n, 
                summary:$s,
                embedding:$emb
            })

            MERGE (r:Risk {level:$rl})
            MERGE (rr:RiskReason {text:$rr})
            MERGE (o:Obligation {text:$ob})
            MERGE (l:Liability {text:$li})
            MERGE (ai:AISummary {text:$ai})

            CREATE (c)-[:HAS_CLAUSE]->(cl)
            CREATE (cl)-[:HAS_RISK]->(r)
            CREATE (cl)-[:HAS_REASON]->(rr)
            CREATE (cl)-[:HAS_OBLIGATION]->(o)
            CREATE (cl)-[:HAS_LIABILITY]->(l)
            CREATE (cl)-[:HAS_AI_SUMMARY]->(ai)
            """,
            id=cid,
            n=safe_str(cl.get("clause_name")),
            s=safe_str(cl.get("summary")),
            rl=safe_str(cl.get("risk_level")),
            rr=safe_str(cl.get("risk_reason")),
            ob=safe_str(cl.get("obligation")),
            li=safe_str(cl.get("liability")),
            ai=safe_str(cl.get("ai_summary")),
            emb=clause_emb
            )

    print("✅ Stored successfully with vector embeddings")
    return state

# %%
graph = StateGraph(ContractState)

graph.add_node("extract", pdf_extraction_agent)
graph.add_node("embed", embedding_agent)
graph.add_node("analyze", analysis_agent)
graph.add_node("store", store_graph_agent)

graph.set_entry_point("extract")

graph.add_edge("extract", "embed")
graph.add_edge("embed", "analyze")
graph.add_edge("analyze", "store")
graph.add_edge("store", END)

workflow = graph.compile()
print("✅ LangGraph workflow ready")
# Out:
# ✅ LangGraph workflow ready

# %%
def retrieve_contract_from_db(contract_id):
    """
    Retrieve complete contract details from Neo4j database
    """
    print(f"\n🔍 Retrieving contract: {contract_id}")
    
    with neo4j_driver.session() as s:
        # Get contract with all related data
        result = s.run("""
        MATCH (c:Contract {id:$id})
        OPTIONAL MATCH (c)<-[:IS_PARTY_TO]-(org:Organization)
        OPTIONAL MATCH (c)-[:HAS_DATE]->(dt:ImportantDate)
        OPTIONAL MATCH (c)-[:HAS_CLAUSE]->(cl:Clause)
        OPTIONAL MATCH (cl)-[:HAS_RISK]->(r:Risk)
        OPTIONAL MATCH (cl)-[:HAS_REASON]->(rr:RiskReason)
        OPTIONAL MATCH (cl)-[:HAS_OBLIGATION]->(o:Obligation)
        OPTIONAL MATCH (cl)-[:HAS_LIABILITY]->(l:Liability)
        OPTIONAL MATCH (cl)-[:HAS_AI_SUMMARY]->(ai:AISummary)
        
        RETURN c.title as title,
               c.file_name as file_name,
               c.id as contract_id,
               c.governing_law as governing_law,
               collect(DISTINCT org.name) as parties,
               collect(DISTINCT dt.value) as dates,
               collect(DISTINCT {
                   clause_name: cl.name,
                   summary: cl.summary,
                   risk_level: r.level,
                   risk_reason: rr.text,
                   obligation: o.text,
                   liability: l.text,
                   ai_summary: ai.text
               }) as clauses
        """, id=contract_id)
        
        record = result.single()
        if record:
            data = {
                "title": record["title"],
                "file_name": record["file_name"],
                "contract_id": record["contract_id"],
                "governing_law": record["governing_law"],
                "parties": [p for p in record["parties"] if p],
                "dates": [d for d in record["dates"] if d],
                "clauses": [c for c in record["clauses"] if c.get("clause_name")]
            }
            print("✅ Contract retrieved successfully")
            return data
        else:
            print("❌ Contract not found")
            return None

def retrieve_all_contracts():
    """
    Retrieve all contracts from database
    """
    print("\n📚 Retrieving all contracts...")
    
    with neo4j_driver.session() as s:
        result = s.run("""
        MATCH (c:Contract)
        RETURN c.id as id, c.title as title, c.file_name as file_name
        """)
        
        contracts = []
        for record in result:
            contracts.append({
                "id": record["id"],
                "title": record["title"],
                "file_name": record["file_name"]
            })
        
        print(f"✅ Found {len(contracts)} contracts")
        return contracts

def search_similar_clauses(query_text, top_k=5):
    """
    Search for similar clauses using vector embeddings
    """
    print(f"\n🔍 Searching for clauses similar to: '{query_text}'")
    
    # Generate embedding for query via API
    query_emb = get_embeddings_api(query_text)
    
    if query_emb is None:
        print("❌ Could not generate query embedding")
        return []
    
    # Normalize if nested
    if isinstance(query_emb[0], list):
        query_emb = query_emb[0]
    
    with neo4j_driver.session() as s:
        # Get all clauses with embeddings
        result = s.run("""
        MATCH (c:Contract)-[:HAS_CLAUSE]->(cl:Clause)
        WHERE cl.embedding IS NOT NULL
        RETURN c.title as contract_title,
               cl.name as clause_name,
               cl.summary as summary,
               cl.embedding as embedding
        """)
        
        clauses = []
        for record in result:
            # Calculate cosine similarity
            emb = np.array(record["embedding"])
            query = np.array(query_emb)
            
            # Handle different embedding dimensions
            if len(emb) != len(query):
                continue
            
            similarity = np.dot(emb, query) / (np.linalg.norm(emb) * np.linalg.norm(query))
            
            clauses.append({
                "contract": record["contract_title"],
                "clause": record["clause_name"],
                "summary": record["summary"],
                "similarity": float(similarity)
            })
        
        # Sort by similarity
        clauses.sort(key=lambda x: x["similarity"], reverse=True)
        
        print(f"\n📊 Top {top_k} similar clauses:")
        for i, clause in enumerate(clauses[:top_k], 1):
            print(f"\n[{i}] Similarity: {clause['similarity']:.4f}")
            print(f"    Contract: {clause['contract']}")
            print(f"    Clause: {clause['clause']}")
            print(f"    Summary: {clause['summary']}")
        
        return clauses[:top_k]

# %%
# ===== PROCESS CONTRACTS =====
pdfs = [
    "Legal-Services-Agreement.pdf",
    "Employment_contract.pdf",
    "sample_contract.pdf"
]

contract_ids = []

for pdf in pdfs:
    cid = pdf_hash(pdf)
    contract_ids.append(cid)

    print("\n" + "="*80)
    print(f"🚀 Processing: {pdf}")
    print("="*80)

    workflow.invoke({
        "pdf_path": pdf,
        "cid": cid,
        "text": "",
        "embeddings": [],
        "analysis": {},
    })
# Out:
# ================================================================================
# 🚀 Processing: Legal-Services-Agreement.pdf
# ================================================================================
#
# 📄 Extracting PDF: Legal-Services-Agreement.pdf
# 🔢 Generating embeddings via HuggingFace API
# ⚠️ Using fallback embeddings
#    Embedding dimension: 384
# 🧠 Analyzing contract via Groq LLM
# ✅ Analysis complete - Found 12 clauses
# 🗄️ Storing into Neo4j with vector embeddings
# ✅ Stored successfully with vector embeddings
#
# ================================================================================
# 🚀 Processing: Employment_contract.pdf
# ================================================================================
#
# 📄 Extracting PDF: Employment_contract.pdf
# 🔢 Generating embeddings via HuggingFace API
# ⚠️ Using fallback embeddings
#    Embedding dimension: 384
# 🧠 Analyzing contract via Groq LLM
# ✅ Analysis complete - Found 13 clauses
# 🗄️ Storing into Neo4j with vector embeddings
# ✅ Stored successfully with vector embeddings
#
# ================================================================================
# 🚀 Processing: sample_contract.pdf
# ================================================================================
#
# 📄 Extracting PDF: sample_contract.pdf
# 🔢 Generating embeddings via HuggingFace API
# ⚠️ Using fallback embeddings
#    Embedding dimension: 384
# 🧠 Analyzing contract via Groq LLM
# ✅ Analysis complete - Found 6 clauses
# 🗄️ Storing into Neo4j with vector embeddings
# ✅ Stored successfully with vector embeddings

# %%
# ===== RETRIEVE AND DISPLAY RESULTS FOR ALL CONTRACTS =====

print("\n\n" + "#"*80)
print("# RETRIEVING ALL STORED CONTRACTS FROM DATABASE")
print("#"*80)

# Check if required functions are defined
try:
    # Test if functions exist
    if 'retrieve_all_contracts' not in globals():
        raise NameError("retrieve_all_contracts function not found")
    if 'retrieve_contract_from_db' not in globals():
        raise NameError("retrieve_contract_from_db function not found")
    if 'print_contract_summary' not in globals():
        raise NameError("print_contract_summary function not found")
    
    # Get all contracts from database
    all_contracts = retrieve_all_contracts()
    
    if not all_contracts:
        print("\n❌ No contracts found in database")
    else:
        print(f"\n📊 Found {len(all_contracts)} contract(s) in database")
        print("="*80)
        
        # Retrieve and display summary for EACH contract
        for i, contract in enumerate(all_contracts, 1):
            print(f"\n\n{'='*80}")
            print(f"📄 CONTRACT {i} of {len(all_contracts)}")
            print(f"{'='*80}")
            
            try:
                contract_data = retrieve_contract_from_db(contract['id'])
                if contract_data:
                    print_contract_summary(contract_data)
                else:
                    print(f"❌ Could not retrieve details for: {contract['title']}")
            except Exception as e:
                print(f"❌ Error retrieving contract {contract['title']}: {str(e)}")
                continue
        
        print(f"\n\n{'='*80}")
        print(f"✅ Displayed summaries for {len(all_contracts)} contract(s)")
        print(f"{'='*80}")
        
except NameError as e:
    print(f"\n❌ ERROR: {str(e)}")
    print("\n💡 SOLUTION: Please run the cells in order:")
    print("   1. Run all cells from the beginning")
    print("   2. Make sure the cell containing 'retrieve_all_contracts' function is executed")
    print("   3. Then run this cell again")
    print("\n   Or run: Kernel -> Restart & Run All")
    
except Exception as e:
    print(f"\n❌ Unexpected error: {str(e)}")
    print("💡 Check your Neo4j connection and try again")
# Out:
# ################################################################################
# # RETRIEVING ALL STORED CONTRACTS FROM DATABASE
# ################################################################################
#
# 📚 Retrieving all contracts...
# ✅ Found 3 contracts
#
# 📊 Found 3 contract(s) in database
# ================================================================================
#
#
# ================================================================================
# 📄 CONTRACT 1 of 3
# ================================================================================
#
# 🔍 Retrieving contract: 1de79b4ffc94b68989ab72c79d929fc5169e8c48b1ea78fc7ee7c8bcd0b1c7d2
# ✅ Contract retrieved successfully
#
# ================================================================================
# 📄 CONTRACT SUMMARY
# ================================================================================
#
# 📌 BASIC INFORMATION
# --------------------------------------------------------------------------------
# Title          : Legal Services Agreement
# File Name      : Legal-Services-Agreement.pdf
# Contract ID    : 1de79b4ffc94b68989ab72c79d929fc5169e8c48b1ea78fc7ee7c8bcd0b1c7d2
# Governing Law  : California law
#
# 👥 PARTIES (2)
# --------------------------------------------------------------------------------
#   [1] Law Firm
#   [2] Client
#
# 📅 IMPORTANT DATES (1)
# --------------------------------------------------------------------------------
#   [1] Not specified
#
# ⚖️ CLAUSE RISK ANALYSIS (62)
# ================================================================================
#
# [Clause 1] Identification of Parties
# --------------------------------------------------------------------------------
# Summary      : This clause identifies the parties involved in the agreement.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply identifies the parties involved.
#
# 📋 Obligation : The parties must agree to the terms of the agreement.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause is a standard identification of parties clause. It does not pose any significant risks as it simply identifies the parties involved. The parties must agree to the terms of the agreement. There is no liability associated with this clause.
# --------------------------------------------------------------------------------
#
# [Clause 2] Conditions
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the conditions under which the agreement will take effect.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the conditions under which the agreement will take effect. If the client fails to return a signed copy of the agreement, the agreement will not take effect, and the law firm will have no obligation to provide legal services.
#
# 📋 Obligation : The client must return a signed copy of the agreement.
# 💼 Liability  : The law firm has no liability if the client fails to return a signed copy of the agreement.
#
# 🤖 AI Summary : This clause outlines the conditions under which the agreement will take effect. If the client fails to return a signed copy of the agreement, the agreement will not take effect, and the law firm will have no obligation to provide legal services. The client must return a signed copy of the agreement. The law firm has no liability if the client fails to return a signed copy of the agreement.
# --------------------------------------------------------------------------------
#
# [Clause 3] Responsibilities of Law Firm and Client
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the responsibilities of the law firm and the client.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the responsibilities of the law firm and the client. If the client fails to provide information and documents necessary to the law firm's effective representation, the law firm may not be able to adequately represent and advise the client.
#
# 📋 Obligation : The client must provide information and documents necessary to the law firm's effective representation.
# 💼 Liability  : The client may be liable if they fail to provide information and documents necessary to the law firm's effective representation.
#
# 🤖 AI Summary : This clause outlines the responsibilities of the law firm and the client. The law firm must perform the legal services called for under the agreement, keep the client informed of progress and developments, and respond within a reasonable time to the client's inquiries and communications. The client must be truthful and cooperative with the law firm, provide on a timely basis all information and documents necessary to the law firm's effective representation, keep the law firm reasonably informed of developments and of the client's address, telephone number, and whereabouts, timely make any payments required by the agreement, and abide by the agreement. The client may be liable if they fail to provide information and documents necessary to the law firm's effective representation.
# --------------------------------------------------------------------------------
#
# [Clause 4] Retention of Firm Rather Than Particular Attorney
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the fact that the client is retaining the law firm, not a particular attorney.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply outlines the fact that the client is retaining the law firm, not a particular attorney.
#
# 📋 Obligation : None
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the fact that the client is retaining the law firm, not a particular attorney. This clause does not pose any significant risks as it simply outlines the fact that the client is retaining the law firm, not a particular attorney.
# --------------------------------------------------------------------------------
#
# [Clause 5] Delegation of Services
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the fact that the law firm includes more than one attorney, and that one or more attorneys may be utilized in the proceedings involving the client's case.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the fact that the law firm includes more than one attorney, and that one or more attorneys may be utilized in the proceedings involving the client's case. This may lead to confusion and inconsistent representation.
#
# 📋 Obligation : None
# 💼 Liability  : The law firm may be liable if they fail to properly delegate services.
#
# 🤖 AI Summary : This clause outlines the fact that the law firm includes more than one attorney, and that one or more attorneys may be utilized in the proceedings involving the client's case. This may lead to confusion and inconsistent representation. The law firm may be liable if they fail to properly delegate services.
# --------------------------------------------------------------------------------
#
# [Clause 6] Payment Terms
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the payment terms of the agreement.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the payment terms of the agreement. If the client fails to pay the agreed-upon fees, the law firm may have to take action to collect the debt.
#
# 📋 Obligation : The client must pay the agreed-upon fees.
# 💼 Liability  : The client may be liable if they fail to pay the agreed-upon fees.
#
# 🤖 AI Summary : This clause outlines the payment terms of the agreement. The client must pay the agreed-upon fees. The client may be liable if they fail to pay the agreed-upon fees. The law firm may have to take action to collect the debt if the client fails to pay the agreed-upon fees.
# --------------------------------------------------------------------------------
#
# [Clause 7] Termination
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the circumstances under which the agreement may be terminated.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the circumstances under which the agreement may be terminated. If the client fails to pay the agreed-upon fees, the law firm may have to take action to collect the debt.
#
# 📋 Obligation : The client must pay the agreed-upon fees.
# 💼 Liability  : The client may be liable if they fail to pay the agreed-upon fees.
#
# 🤖 AI Summary : This clause outlines the circumstances under which the agreement may be terminated. The client may terminate the agreement by written notice. The law firm may also terminate the agreement if the client fails to pay the agreed-upon fees. The client must pay the agreed-upon fees. The client may be liable if they fail to pay the agreed-upon fees.
# --------------------------------------------------------------------------------
#
# [Clause 8] Liability
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the liability of the law firm and the client.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the liability of the law firm and the client. If the law firm fails to properly represent the client, the client may be liable for any damages or losses incurred.
#
# 📋 Obligation : The law firm must properly represent the client.
# 💼 Liability  : The client may be liable if the law firm fails to properly represent them.
#
# 🤖 AI Summary : This clause outlines the liability of the law firm and the client. The law firm must properly represent the client. The client may be liable if the law firm fails to properly represent them. If the law firm fails to properly represent the client, the client may be liable for any damages or losses incurred.
# --------------------------------------------------------------------------------
#
# [Clause 9] Intellectual Property
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the ownership of intellectual property created during the course of the agreement.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply outlines the ownership of intellectual property created during the course of the agreement.
#
# 📋 Obligation : None
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the ownership of intellectual property created during the course of the agreement. The client retains ownership of all intellectual property created during the course of the agreement. This clause does not pose any significant risks as it simply outlines the ownership of intellectual property created during the course of the agreement.
# --------------------------------------------------------------------------------
#
# [Clause 10] Confidentiality
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the confidentiality obligations of the law firm and the client.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the confidentiality obligations of the law firm and the client. If the law firm fails to maintain confidentiality, the client's confidential information may be disclosed.
#
# 📋 Obligation : The law firm must maintain confidentiality.
# 💼 Liability  : The law firm may be liable if they fail to maintain confidentiality.
#
# 🤖 AI Summary : This clause outlines the confidentiality obligations of the law firm and the client. The law firm must maintain confidentiality. The law firm may be liable if they fail to maintain confidentiality. If the law firm fails to maintain confidentiality, the client's confidential information may be disclosed.
# --------------------------------------------------------------------------------
#
# [Clause 11] Warranties
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the warranties of the law firm and the client.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the warranties of the law firm and the client. If the law firm fails to provide services in accordance with the agreement, the client may be entitled to damages.
#
# 📋 Obligation : The law firm must provide services in accordance with the agreement.
# 💼 Liability  : The client may be entitled to damages if the law firm fails to provide services in accordance with the agreement.
#
# 🤖 AI Summary : This clause outlines the warranties of the law firm and the client. The law firm must provide services in accordance with the agreement. The client may be entitled to damages if the law firm fails to provide services in accordance with the agreement. If the law firm fails to provide services in accordance with the agreement, the client may be entitled to damages.
# --------------------------------------------------------------------------------
#
# [Clause 12] Indemnification
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the indemnification obligations of the law firm and the client.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the indemnification obligations of the law firm and the client. If the client fails to indemnify the law firm, the law firm may be liable for any damages or losses incurred.
#
# 📋 Obligation : The client must indemnify the law firm.
# 💼 Liability  : The law firm may be liable if the client fails to indemnify them.
#
# 🤖 AI Summary : This clause outlines the indemnification obligations of the law firm and the client. The client must indemnify the law firm. The law firm may be liable if the client fails to indemnify them. If the client fails to indemnify the law firm, the law firm may be liable for any damages or losses incurred.
# --------------------------------------------------------------------------------
#
# [Clause 13] Identification of Parties
# --------------------------------------------------------------------------------
# Summary      : This clause identifies the parties involved in the agreement.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply identifies the parties involved.
#
# 📋 Obligation : The parties must be identified and agreed upon.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause is a standard identification of parties clause. It does not pose any significant risks or liabilities. The parties must be identified and agreed upon, but this is a standard requirement in any agreement.
# --------------------------------------------------------------------------------
#
# [Clause 14] Conditions
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the conditions under which the agreement will take effect.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it requires the client to return a signed copy of the agreement and pay the required fee. If the client fails to do so, the agreement will not take effect, and the law firm will have no obligation to provide services.
#
# 📋 Obligation : The client must return a signed copy of the agreement and pay the required fee.
# 💼 Liability  : The law firm has no liability if the client fails to meet the conditions.
#
# 🤖 AI Summary : This clause outlines the conditions under which the agreement will take effect. The client must return a signed copy of the agreement and pay the required fee. If the client fails to do so, the agreement will not take effect, and the law firm will have no obligation to provide services. This clause poses a medium risk as it requires the client to take specific actions to meet the conditions.
# --------------------------------------------------------------------------------
#
# [Clause 15] Responsibilities of Law Firm and Client
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the responsibilities of the law firm and the client.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it requires the client to be truthful and cooperative with the law firm, provide necessary information and documents, and keep the law firm informed of developments. If the client fails to meet these responsibilities, the law firm may not be able to adequately represent and advise the client.
#
# 📋 Obligation : The client must be truthful and cooperative with the law firm, provide necessary information and documents, and keep the law firm informed of developments.
# 💼 Liability  : The client may be liable for any damages or losses resulting from their failure to meet their responsibilities.
#
# 🤖 AI Summary : This clause outlines the responsibilities of the law firm and the client. The client must be truthful and cooperative with the law firm, provide necessary information and documents, and keep the law firm informed of developments. If the client fails to meet these responsibilities, the law firm may not be able to adequately represent and advise the client. This clause poses a high risk as it requires the client to take specific actions to meet their responsibilities.
# --------------------------------------------------------------------------------
#
# [Clause 16] Retention of Firm Rather Than Particular Attorney
# --------------------------------------------------------------------------------
# Summary      : This clause states that the client is retaining the law firm, not a particular attorney.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the client is retaining the law firm, not a particular attorney.
#
# 📋 Obligation : The client must understand that they are retaining the law firm, not a particular attorney.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause states that the client is retaining the law firm, not a particular attorney. This clause does not pose any significant risks or liabilities. The client must understand that they are retaining the law firm, not a particular attorney.
# --------------------------------------------------------------------------------
#
# [Clause 17] Delegation of Services
# --------------------------------------------------------------------------------
# Summary      : This clause states that the law firm may delegate services to other attorneys or support personnel.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it requires the client to understand that the law firm may delegate services to other attorneys or support personnel. If the client is not aware of this, they may not be able to effectively communicate with the law firm or understand the services being provided.
#
# 📋 Obligation : The client must understand that the law firm may delegate services to other attorneys or support personnel.
# 💼 Liability  : The law firm may be liable for any damages or losses resulting from the delegation of services.
#
# 🤖 AI Summary : This clause states that the law firm may delegate services to other attorneys or support personnel. This clause poses a medium risk as it requires the client to understand that the law firm may delegate services to other attorneys or support personnel. If the client is not aware of this, they may not be able to effectively communicate with the law firm or understand the services being provided.
# --------------------------------------------------------------------------------
#
# [Clause 18] Legal Services to be Provided
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the legal services to be provided by the law firm.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it requires the law firm to provide specific legal services, including the preparation of documents. If the law firm fails to provide these services, the client may not receive the representation they need.
#
# 📋 Obligation : The law firm must provide the legal services outlined in this clause.
# 💼 Liability  : The law firm may be liable for any damages or losses resulting from their failure to provide the legal services.
#
# 🤖 AI Summary : This clause outlines the legal services to be provided by the law firm. The law firm must provide the legal services outlined in this clause. If the law firm fails to provide these services, the client may not receive the representation they need. This clause poses a high risk as it requires the law firm to take specific actions to provide the legal services.
# --------------------------------------------------------------------------------
#
# [Clause 19] Fees/Deposit
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the fees and deposit required by the law firm.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it requires the client to pay the fees and deposit required by the law firm. If the client fails to pay these fees, the law firm may not be able to provide the legal services.
#
# 📋 Obligation : The client must pay the fees and deposit required by the law firm.
# 💼 Liability  : The client may be liable for any damages or losses resulting from their failure to pay the fees and deposit.
#
# 🤖 AI Summary : This clause outlines the fees and deposit required by the law firm. The client must pay the fees and deposit required by the law firm. If the client fails to pay these fees, the law firm may not be able to provide the legal services. This clause poses a medium risk as it requires the client to take specific actions to pay the fees and deposit.
# --------------------------------------------------------------------------------
#
# [Clause 20] Extra Costs
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the extra costs that may be incurred by the law firm.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it requires the client to pay for extra costs, including copying costs and preparation of documents. If the client fails to pay these costs, the law firm may not be able to provide the legal services.
#
# 📋 Obligation : The client must pay for extra costs, including copying costs and preparation of documents.
# 💼 Liability  : The client may be liable for any damages or losses resulting from their failure to pay the extra costs.
#
# 🤖 AI Summary : This clause outlines the extra costs that may be incurred by the law firm. The client must pay for extra costs, including copying costs and preparation of documents. If the client fails to pay these costs, the law firm may not be able to provide the legal services. This clause poses a high risk as it requires the client to take specific actions to pay the extra costs.
# --------------------------------------------------------------------------------
#
# [Clause 21] Statements and Payments
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the statements and payments required by the law firm.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it requires the client to pay for statements and payments, including a service charge on delinquent balances. If the client fails to pay these charges, the law firm may take action to collect the debt.
#
# 📋 Obligation : The client must pay for statements and payments, including a service charge on delinquent balances.
# 💼 Liability  : The client may be liable for any damages or losses resulting from their failure to pay the statements and payments.
#
# 🤖 AI Summary : This clause outlines the statements and payments required by the law firm. The client must pay for statements and payments, including a service charge on delinquent balances. If the client fails to pay these charges, the law firm may take action to collect the debt. This clause poses a medium risk as it requires the client to take specific actions to pay the statements and payments.
# --------------------------------------------------------------------------------
#
# [Clause 22] Delinquent Accounts
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the consequences of delinquent accounts.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it requires the client to pay all costs of collection plus a service charge on delinquent balances. If the client fails to pay these charges, the law firm may take action to collect the debt.
#
# 📋 Obligation : The client must pay all costs of collection plus a service charge on delinquent balances.
# 💼 Liability  : The client may be liable for any damages or losses resulting from their failure to pay the costs of collection and service charge.
#
# 🤖 AI Summary : This clause outlines the consequences of delinquent accounts. The client must pay all costs of collection plus a service charge on delinquent balances. If the client fails to pay these charges, the law firm may take action to collect the debt. This clause poses a high risk as it requires the client to take specific actions to pay the costs of collection and service charge.
# --------------------------------------------------------------------------------
#
# [Clause 23] Acceptance of Charges
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the client's acceptance of charges.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it requires the client to notify the law firm in writing of any billing error or dispute within 30 days from the date of the statement. If the client fails to do so, the statement will be deemed to have been accepted by the client.
#
# 📋 Obligation : The client must notify the law firm in writing of any billing error or dispute within 30 days from the date of the statement.
# 💼 Liability  : The client may be liable for any damages or losses resulting from their failure to notify the law firm of any billing error or dispute.
#
# 🤖 AI Summary : This clause outlines the client's acceptance of charges. The client must notify the law firm in writing of any billing error or dispute within 30 days from the date of the statement. If the client fails to do so, the statement will be deemed to have been accepted by the client. This clause poses a medium risk as it requires the client to take specific actions to notify the law firm of any billing error or dispute.
# --------------------------------------------------------------------------------
#
# [Clause 24] Discharge of Law Firm
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the client's ability to discharge the law firm.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the client may discharge the law firm at any time by written notice.
#
# 📋 Obligation : The client must provide written notice to the law firm to discharge them.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the client's ability to discharge the law firm. The client must provide written notice to the law firm to discharge them. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 25] Withdrawal of Law Firm
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the law firm's ability to withdraw from the representation.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it requires the law firm to withdraw from the representation if the client fails to pay attorneys' fees or costs as required by their agreement with the law firm.
#
# 📋 Obligation : The law firm must withdraw from the representation if the client fails to pay attorneys' fees or costs as required by their agreement with the law firm.
# 💼 Liability  : The law firm may be liable for any damages or losses resulting from their withdrawal from the representation.
#
# 🤖 AI Summary : This clause outlines the law firm's ability to withdraw from the representation. The law firm must withdraw from the representation if the client fails to pay attorneys' fees or costs as required by their agreement with the law firm. This clause poses a medium risk as it requires the law firm to take specific actions to withdraw from the representation.
# --------------------------------------------------------------------------------
#
# [Clause 26] Release of Client's Papers and Property
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the law firm's release of the client's papers and property.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the law firm will release the client's papers and property upon request.
#
# 📋 Obligation : The client must request the release of their papers and property in writing.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the law firm's release of the client's papers and property. The client must request the release of their papers and property in writing. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 27] Disclaimer of Guaranty
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the law firm's disclaimer of guaranty.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the law firm cannot guarantee any particular result.
#
# 📋 Obligation : The law firm must inform the client that they cannot guarantee any particular result.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the law firm's disclaimer of guaranty. The law firm must inform the client that they cannot guarantee any particular result. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 28] Errors & Omissions Coverage
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the law firm's errors and omissions coverage.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the law firm maintains errors and omissions insurance.
#
# 📋 Obligation : The law firm must maintain errors and omissions insurance.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the law firm's errors and omissions coverage. The law firm must maintain errors and omissions insurance. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 29] Entire Agreement
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the entire agreement between the parties.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the agreement contains the entire agreement of the parties.
#
# 📋 Obligation : The parties must agree that the agreement contains the entire agreement.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the entire agreement between the parties. The parties must agree that the agreement contains the entire agreement. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 30] Severability in Event of Partial Invalidity
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the severability of the agreement in the event of partial invalidity.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that if any provision of the agreement is held in whole or in part to be unenforceable, the remainder of that provision will be severable and remain in effect.
#
# 📋 Obligation : The parties must agree that if any provision of the agreement is held in whole or in part to be unenforceable, the remainder of that provision will be severable and remain in effect.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the severability of the agreement in the event of partial invalidity. The parties must agree that if any provision of the agreement is held in whole or in part to be unenforceable, the remainder of that provision will be severable and remain in effect. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 31] Modification by Subsequent Agreement
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the modification of the agreement by subsequent agreement.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the agreement may be modified by subsequent agreement of the parties only by an instrument in writing signed by both of them or an oral agreement to the extent that the parties carry it out.
#
# 📋 Obligation : The parties must agree that the agreement may be modified by subsequent agreement of the parties only by an instrument in writing signed by both of them or an oral agreement to the extent that the parties carry it out.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the modification of the agreement by subsequent agreement. The parties must agree that the agreement may be modified by subsequent agreement of the parties only by an instrument in writing signed by both of them or an oral agreement to the extent that the parties carry it out. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 32] Document Retention
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the law firm's document retention policy.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply states that the law firm will retain the client's file in their storage facility for a period of not more than seven years.
#
# 📋 Obligation : The law firm must retain the client's file in their storage facility for a period of not more than seven years.
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the law firm's document retention policy. The law firm must retain the client's file in their storage facility for a period of not more than seven years. This clause does not pose any significant risks or liabilities.
# --------------------------------------------------------------------------------
#
# [Clause 33] Conditions
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the conditions under which the agreement will take effect.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the conditions under which the agreement will take effect. If the client fails to return a signed copy of the agreement, the agreement will not take effect, and the law firm will have no obligation to provide legal services.
#
# 📋 Obligation : The client must return a signed copy of the agreement.
# 💼 Liability  : The law firm has no liability if the client fails to return a signed copy of the agreement.
#
# 🤖 AI Summary : This clause outlines the conditions under which the agreement will take effect. If the client fails to return a signed copy of the agreement, the agreement will not take effect, and the law firm will have no obligation to provide legal services. The law firm has no liability if the client fails to return a signed copy of the agreement. The client must return a signed copy of the agreement to ensure that the agreement takes effect.
# --------------------------------------------------------------------------------
#
# [Clause 34] Responsibilities of Law Firm and Client
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the responsibilities of the law firm and the client.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the responsibilities of the law firm and the client. If the client fails to provide information and documents necessary to the law firm's effective representation, the law firm may not be able to adequately represent and advise the client.
#
# 📋 Obligation : The client must provide information and documents necessary to the law firm's effective representation.
# 💼 Liability  : The client may be liable if they fail to provide information and documents necessary to the law firm's effective representation.
#
# 🤖 AI Summary : This clause outlines the responsibilities of the law firm and the client. The law firm must perform the legal services called for under the agreement, keep the client informed of progress and developments, and respond within a reasonable time to the client's inquiries and communications. The client must be truthful and cooperative with the law firm, provide on a timely basis all information and documents necessary to the law firm's effective representation, and keep the law firm reasonably informed of developments and of the client's address, telephone number, and whereabouts. If the client fails to provide information and documents necessary to the law firm's effective representation, the law firm may not be able to adequately represent and advise the client, and the client may be liable.
# --------------------------------------------------------------------------------
#
# [Clause 35] Delegation of Services
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the fact that the law firm includes more than one attorney, and that one or more attorneys may be utilized in the proceedings involving the client's case.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it simply outlines the fact that the law firm includes more than one attorney, and that one or more attorneys may be utilized in the proceedings involving the client's case.
#
# 📋 Obligation : None
# 💼 Liability  : None
#
# 🤖 AI Summary : This clause outlines the fact that the law firm includes more than one attorney, and that one or more attorneys may be utilized in the proceedings involving the client's case. This clause does not pose any significant risks as it simply outlines the fact that the law firm includes more than one attorney, and that one or more attorneys may be utilized in the proceedings involving the client's case.
# --------------------------------------------------------------------------------
#
# [Clause 36] Legal Services to Be Provided
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the legal services to be provided by the law firm to the client.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the legal services to be provided by the law firm to the client. If the client requests additional services not covered by the agreement, a separate written agreement between the law firm and the client will be required.
#
# 📋 Obligation : The law firm must provide the legal services outlined in the agreement.
# 💼 Liability  : The law firm may be liable if they fail to provide the legal services outlined in the agreement.
#
# 🤖 AI Summary : This clause outlines the legal services to be provided by the law firm to the client. The law firm must provide the legal services outlined in the agreement, including the preparation of documents such as a revocable living trust, schedule A, and assignment of personal property to revocable living trust. If the client requests additional services not covered by the agreement, a separate written agreement between the law firm and the client will be required. The law firm may be liable if they fail to provide the legal services outlined in the agreement.
# --------------------------------------------------------------------------------
#
# [Clause 37] Fees/Deposit
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the fees and deposit required by the law firm.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the fees and deposit required by the law firm. If the client fails to pay the fees and deposit, the law firm may have a lien on any sums recovered, whether by settlement or judgment, on account of the claims of the client.
#
# 📋 Obligation : The client must pay the fees and deposit required by the law firm.
# 💼 Liability  : The client may be liable if they fail to pay the fees and deposit required by the law firm.
#
# 🤖 AI Summary : This clause outlines the fees and deposit required by the law firm. The client must pay the fees and deposit required by the law firm, which will be billed according to the rate schedule attached to the agreement. If the client fails to pay the fees and deposit, the law firm may have a lien on any sums recovered, whether by settlement or judgment, on account of the claims of the client. The client may be liable if they fail to pay the fees and deposit required by the law firm.
# --------------------------------------------------------------------------------
#
# [Clause 38] Extra Costs
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the extra costs that the law firm may incur in performing legal services under the agreement.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the extra costs that the law firm may incur in performing legal services under the agreement. If the client requests additional copies of their estate planning documents, they will be charged according to the rate schedule attached to the agreement.
#
# 📋 Obligation : The client must pay for any extra costs incurred by the law firm.
# 💼 Liability  : The client may be liable if they fail to pay for any extra costs incurred by the law firm.
#
# 🤖 AI Summary : This clause outlines the extra costs that the law firm may incur in performing legal services under the agreement. The client must pay for any extra costs incurred by the law firm, including copying costs and preparation of documents to transfer assets. If the client requests additional copies of their estate planning documents, they will be charged according to the rate schedule attached to the agreement. The client may be liable if they fail to pay for any extra costs incurred by the law firm.
# --------------------------------------------------------------------------------
#
# [Clause 39] Statements and Payments
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the statements and payments required by the law firm.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the statements and payments required by the law firm. If the client fails to pay their account in full when it becomes due, they will be liable for all costs of collection plus a service charge on any delinquent balance.
#
# 📋 Obligation : The client must pay their account in full when it becomes due.
# 💼 Liability  : The client may be liable if they fail to pay their account in full when it becomes due.
#
# 🤖 AI Summary : This clause outlines the statements and payments required by the law firm. The law firm will send the client monthly statements indicating attorneys' fees and costs incurred and their basis, and any current balance owed. The client must pay their account in full when it becomes due, and if they fail to do so, they will be liable for all costs of collection plus a service charge on any delinquent balance. The client may be liable if they fail to pay their account in full when it becomes due.
# --------------------------------------------------------------------------------
#
# [Clause 40] Delinquent Accounts
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the consequences of delinquent accounts.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it outlines the consequences of delinquent accounts. If the client fails to pay their account in full when it becomes due, they will be liable for all costs of collection plus a service charge on any delinquent balance.
#
# 📋 Obligation : The client must pay their account in full when it becomes due.
# 💼 Liability  : The client may be liable if they fail to pay their account in full when it becomes due.
#
# 🤖 AI Summary : This clause outlines the consequences of delinquent accounts. If the client fails to pay their account in full when it becomes due, they will be liable for all costs of collection plus a service charge on any delinquent balance. The client must pay their account in full when it becomes due, and if they fail to do so, they will be liable for all costs of collection plus a service charge on any delinquent balance. The client may be liable if they fail to pay their account in full when it becomes due.
# --------------------------------------------------------------------------------
#
# [Clause 41] Acceptance of Charges
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the client's acceptance of charges.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it outlines the client's acceptance of charges.
#
# 📋 Obligation : The client must notify the law firm in writing of any billing error or dispute within 30 days from the date of the statement which first sets forth the erroneous or disputed charges.
# 💼 Liability  : The client may be liable if they fail to notify the law firm in writing of any billing error or dispute within 30 days from the date of the statement which first sets forth the erroneous or disputed charges.
#
# 🤖 AI Summary : This clause outlines the client's acceptance of charges. The client must notify the law firm in writing of any billing error or dispute within 30 days from the date of the statement which first sets forth the erroneous or disputed charges. If the client fails to do so, the statement will be deemed to have been accepted by the client as an accurate and appropriate billing, and the client will be liable for the charges.
# --------------------------------------------------------------------------------
#
# [Clause 42] Discharge of Law Firm
# --------------------------------------------------------------------------------
# Summary      : This clause outlines the client's ability to discharge the law firm.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose any significant risks as it outlines the client's ability to discharge the law firm.
#
# 📋 Obligation : The client must provide written notice to the law firm to discharge them.
# 💼 Liability  : The client may be liable if they fail to provide written notice to the law firm to discharge them.
#
# ...
#
# 📋 Obligation : Either party may terminate this agreement with 30 days written notice.
# 💼 Liability  : Either party may be liable for damages or losses incurred due to termination.
#
# 🤖 AI Summary : This clause outlines the termination terms, which may lead to disputes if not met. Key takeaway is that either party has the right to terminate the agreement with 30 days written notice. Red flag is that the termination notice period is 30 days, which may not be sufficient for either party to adjust their business operations. Recommendation is to clearly define the termination terms and consider providing a termination schedule to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 10] Confidentiality
# --------------------------------------------------------------------------------
# Summary      : Both parties agree to maintain confidentiality of proprietary information.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose significant risks as it only outlines the confidentiality terms, which are standard in most contracts.
#
# 📋 Obligation : Both parties agree to maintain confidentiality of proprietary information.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the confidentiality terms, which are standard in most contracts. Key takeaway is that both parties are responsible for maintaining confidentiality of proprietary information. Red flag is that the clause does not specify the scope of confidential information. Recommendation is to clearly define the scope of confidential information to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 11] Liability
# --------------------------------------------------------------------------------
# Summary      : XYZ Solutions’ liability shall not exceed the total contract value.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the liability terms, which may lead to disputes if not met. Specific concern is that the liability is capped at the total contract value, which may not be sufficient to cover damages or losses incurred by ABC Technologies. Potential liability is that XYZ Solutions may be liable for damages or losses incurred by ABC Technologies.
#
# 📋 Obligation : XYZ Solutions’ liability shall not exceed the total contract value.
# 💼 Liability  : XYZ Solutions may be liable for damages or losses incurred by ABC Technologies.
#
# 🤖 AI Summary : This clause outlines the liability terms, which may lead to disputes if not met. Key takeaway is that XYZ Solutions’ liability is capped at the total contract value. Red flag is that the liability may not be sufficient to cover damages or losses incurred by ABC Technologies. Recommendation is to clearly define the liability terms and consider providing a liability schedule to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 12] Governing Law
# --------------------------------------------------------------------------------
# Summary      : This agreement shall be governed by the laws of India.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose significant risks as it only outlines the governing law, which is standard in most contracts.
#
# 📋 Obligation : This agreement shall be governed by the laws of India.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the governing law, which is standard in most contracts. Key takeaway is that the agreement shall be governed by the laws of India. Red flag is that the clause does not specify the jurisdiction. Recommendation is to clearly define the jurisdiction to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 13] Scope of Services
# --------------------------------------------------------------------------------
# Summary      : XYZ Solutions shall provide software development services to ABC Technologies.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose significant risks as it only outlines the scope of services to be provided by XYZ Solutions.
#
# 📋 Obligation : XYZ Solutions shall provide software development services to ABC Technologies.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the scope of services to be provided by XYZ Solutions to ABC Technologies. Key takeaways include the specific services to be provided and the parties involved. Red flags or concerns include the potential for scope creep or changes in requirements. Recommendations include clearly defining the scope of services and establishing a change management process.
# --------------------------------------------------------------------------------
#
# [Clause 14] Payment Terms
# --------------------------------------------------------------------------------
# Summary      : ABC Technologies shall pay XYZ Solutions INR 5,00,000 within 30 days of invoice.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines a specific payment term that may not be favorable to XYZ Solutions. The risk level is medium because it may lead to cash flow issues for XYZ Solutions if ABC Technologies delays payment.
#
# 📋 Obligation : ABC Technologies shall pay XYZ Solutions INR 5,00,000 within 30 days of invoice.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the payment terms for the services provided by XYZ Solutions to ABC Technologies. Key takeaways include the specific payment amount and the timeframe for payment. Red flags or concerns include the potential for delayed payment and the impact on XYZ Solutions' cash flow. Recommendations include establishing a payment schedule and ensuring timely payment to avoid any disputes.
# --------------------------------------------------------------------------------
#
# [Clause 15] Termination
# --------------------------------------------------------------------------------
# Summary      : Either party may terminate this agreement with 30 days written notice.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it allows either party to terminate the agreement with 30 days written notice. The risk level is medium because it may lead to uncertainty and potential losses for XYZ Solutions if the agreement is terminated prematurely.
#
# 📋 Obligation : Either party may terminate this agreement with 30 days written notice.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the termination terms for the agreement between ABC Technologies and XYZ Solutions. Key takeaways include the specific notice period and the parties involved. Red flags or concerns include the potential for premature termination and the impact on XYZ Solutions' business. Recommendations include establishing a clear termination process and ensuring that both parties are aware of the terms and conditions.
# --------------------------------------------------------------------------------
#
# [Clause 16] Confidentiality
# --------------------------------------------------------------------------------
# Summary      : Both parties agree to maintain confidentiality of proprietary information.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose significant risks as it only outlines the confidentiality obligations of both parties.
#
# 📋 Obligation : Both parties agree to maintain confidentiality of proprietary information.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the confidentiality obligations of both parties. Key takeaways include the specific information to be kept confidential and the parties involved. Red flags or concerns include the potential for unauthorized disclosure of confidential information. Recommendations include establishing a clear confidentiality agreement and ensuring that both parties are aware of their obligations.
# --------------------------------------------------------------------------------
#
# [Clause 17] Liability
# --------------------------------------------------------------------------------
# Summary      : XYZ Solutions' liability shall not exceed the total contract value.
#
# 🚨 Risk Level : High
# Risk Reason  : This clause poses a high risk as it limits XYZ Solutions' liability to the total contract value. The risk level is high because it may lead to significant financial losses for XYZ Solutions if they are found liable for damages exceeding the contract value.
#
# 📋 Obligation : XYZ Solutions' liability shall not exceed the total contract value.
# 💼 Liability  : Limited to the total contract value
#
# 🤖 AI Summary : This clause outlines the liability terms for XYZ Solutions. Key takeaways include the specific liability limit and the parties involved. Red flags or concerns include the potential for significant financial losses for XYZ Solutions if they are found liable for damages exceeding the contract value. Recommendations include establishing a clear liability limit and ensuring that both parties are aware of their obligations.
# --------------------------------------------------------------------------------
#
# [Clause 18] Governing Law
# --------------------------------------------------------------------------------
# Summary      : This agreement shall be governed by the laws of India.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose significant risks as it only outlines the governing law for the agreement.
#
# 📋 Obligation : This agreement shall be governed by the laws of India.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the governing law for the agreement between ABC Technologies and XYZ Solutions. Key takeaways include the specific governing law and the parties involved. Red flags or concerns include the potential for disputes related to the governing law. Recommendations include establishing a clear governing law and ensuring that both parties are aware of their obligations.
# --------------------------------------------------------------------------------
#
# [Clause 19] Payment Terms
# --------------------------------------------------------------------------------
# Summary      : ABC Technologies shall pay XYZ Solutions INR 5,00,000 within 30 days of invoice.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the payment terms, which may lead to disputes if not met. Specific concerns include the possibility of late payments, which may impact XYZ Solutions' cash flow. Potential liabilities include financial losses due to delayed payments. Unfavorable terms include the possibility of ABC Technologies withholding payments.
#
# 📋 Obligation : ABC Technologies shall pay XYZ Solutions INR 5,00,000 within 30 days of invoice.
# 💼 Liability  : Financial losses due to delayed payments
#
# 🤖 AI Summary : This clause outlines the payment terms, which may lead to disputes if not met. Key takeaway is that ABC Technologies is responsible for paying XYZ Solutions within 30 days of invoice. Red flag is that the payment terms may lead to disputes if not met. Recommendation is to clearly define the payment terms and establish a payment schedule to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 20] Termination
# --------------------------------------------------------------------------------
# Summary      : Either party may terminate this agreement with 30 days written notice.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the termination terms, which may lead to disputes if not met. Specific concerns include the possibility of termination without cause, which may impact XYZ Solutions' business. Potential liabilities include financial losses due to termination. Unfavorable terms include the possibility of ABC Technologies terminating the agreement without cause.
#
# 📋 Obligation : Either party may terminate this agreement with 30 days written notice.
# 💼 Liability  : Financial losses due to termination
#
# 🤖 AI Summary : This clause outlines the termination terms, which may lead to disputes if not met. Key takeaway is that either party may terminate the agreement with 30 days written notice. Red flag is that the termination terms may lead to disputes if not met. Recommendation is to clearly define the termination terms and establish a termination schedule to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 21] Confidentiality
# --------------------------------------------------------------------------------
# Summary      : Both parties agree to maintain confidentiality of proprietary information.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose significant risks as it only outlines the confidentiality terms, which are standard in most contracts.
#
# 📋 Obligation : Both parties agree to maintain confidentiality of proprietary information.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the confidentiality terms, which are standard in most contracts. It does not pose significant risks as it only outlines the confidentiality terms. Key takeaway is that both parties are responsible for maintaining confidentiality of proprietary information. Red flag is that the confidentiality terms may not be clearly defined. Recommendation is to clearly define the confidentiality terms and establish a confidentiality schedule to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 22] Liability
# --------------------------------------------------------------------------------
# Summary      : XYZ Solutions’ liability shall not exceed the total contract value.
#
# 🚨 Risk Level : Medium
# Risk Reason  : This clause poses a medium risk as it outlines the liability terms, which may lead to disputes if not met. Specific concerns include the possibility of XYZ Solutions exceeding the liability limit, which may impact ABC Technologies' business. Potential liabilities include financial losses due to XYZ Solutions exceeding the liability limit. Unfavorable terms include the possibility of XYZ Solutions exceeding the liability limit without notice.
#
# 📋 Obligation : XYZ Solutions’ liability shall not exceed the total contract value.
# 💼 Liability  : Financial losses due to XYZ Solutions exceeding the liability limit
#
# 🤖 AI Summary : This clause outlines the liability terms, which may lead to disputes if not met. Key takeaway is that XYZ Solutions' liability shall not exceed the total contract value. Red flag is that the liability terms may lead to disputes if not met. Recommendation is to clearly define the liability terms and establish a liability schedule to avoid disputes.
# --------------------------------------------------------------------------------
#
# [Clause 23] Governing Law
# --------------------------------------------------------------------------------
# Summary      : This agreement shall be governed by the laws of India.
#
# 🚨 Risk Level : Low
# Risk Reason  : This clause does not pose significant risks as it only outlines the governing law, which is standard in most contracts.
#
# 📋 Obligation : This agreement shall be governed by the laws of India.
# 💼 Liability  : None mentioned
#
# 🤖 AI Summary : This clause outlines the governing law, which is standard in most contracts. It does not pose significant risks as it only outlines the governing law. Key takeaway is that this agreement shall be governed by the laws of India. Red flag is that the governing law may not be clearly defined. Recommendation is to clearly define the governing law and establish a dispute resolution schedule to avoid disputes.
# --------------------------------------------------------------------------------
#
# ================================================================================
#
#
# ================================================================================
# ✅ Displayed summaries for 3 contract(s)
# ================================================================================

# %%
# ===== VIEW INDIVIDUAL CONTRACT GRAPHS =====

def reconnect_neo4j():
    """
    Reconnect to Neo4j if connection is lost
    """
    global neo4j_driver
    
    try:
        # Close existing driver if it exists
        if 'neo4j_driver' in globals():
            try:
                neo4j_driver.close()
            except:
                pass
    except:
        pass
    
    # Re-initialize driver with URI fix
    uri = os.environ["NEO4J_URI"]
    if "neo4j+s://" in uri and "neo4j+ssc://" not in uri:
        uri = uri.replace("neo4j+s://", "neo4j+ssc://")
        print(f"🔄 Updated URI for Aura compatibility: {uri[:50]}...")
    
    neo4j_driver = GraphDatabase.driver(
        uri,
        auth=(os.environ["NEO4J_USERNAME"], os.environ["NEO4J_PASSWORD"])
    )
    
    # Test connection
    try:
        neo4j_driver.verify_connectivity()
        print("✅ Neo4j Aura reconnected successfully!")
        return True
    except Exception as e:
        print(f"❌ Failed to reconnect: {e}")
        return False

def get_contract_cypher_query(contract_id=None, contract_title=None):
    """
    Generate Cypher query to view a single contract graph in Neo4j Browser
    Returns query string you can copy-paste into Neo4j Browser
    """
    if contract_id:
        query = f"""// View Individual Contract Graph by ID
MATCH (c:Contract {{id: "{contract_id}"}})
OPTIONAL MATCH (c)<-[:IS_PARTY_TO]-(o:Organization)
OPTIONAL MATCH (c)-[:HAS_DATE]->(d:ImportantDate)
OPTIONAL MATCH (c)-[:HAS_CLAUSE]->(cl:Clause)
OPTIONAL MATCH (cl)-[:HAS_RISK]->(r:Risk)
OPTIONAL MATCH (cl)-[:HAS_REASON]->(rr:RiskReason)
OPTIONAL MATCH (cl)-[:HAS_OBLIGATION]->(ob:Obligation)
OPTIONAL MATCH (cl)-[:HAS_LIABILITY]->(li:Liability)
OPTIONAL MATCH (cl)-[:HAS_AI_SUMMARY]->(ai:AISummary)
RETURN c, o, d, cl, r, rr, ob, li, ai"""
    elif contract_title:
        query = f"""// View Individual Contract Graph by Title
MATCH (c:Contract {{title: "{contract_title}"}})
OPTIONAL MATCH (c)<-[:IS_PARTY_TO]-(o:Organization)
OPTIONAL MATCH (c)-[:HAS_DATE]->(d:ImportantDate)
OPTIONAL MATCH (c)-[:HAS_CLAUSE]->(cl:Clause)
OPTIONAL MATCH (cl)-[:HAS_RISK]->(r:Risk)
OPTIONAL MATCH (cl)-[:HAS_REASON]->(rr:RiskReason)
OPTIONAL MATCH (cl)-[:HAS_OBLIGATION]->(ob:Obligation)
OPTIONAL MATCH (cl)-[:HAS_LIABILITY]->(li:Liability)
OPTIONAL MATCH (cl)-[:HAS_AI_SUMMARY]->(ai:AISummary)
RETURN c, o, d, cl, r, rr, ob, li, ai"""
    else:
        query = """// View ALL Contracts Together (Explore View)
MATCH (c:Contract)
OPTIONAL MATCH (c)<-[:IS_PARTY_TO]-(o:Organization)
OPTIONAL MATCH (c)-[:HAS_DATE]->(d:ImportantDate)
OPTIONAL MATCH (c)-[:HAS_CLAUSE]->(cl:Clause)
OPTIONAL MATCH (cl)-[:HAS_RISK]->(r:Risk)
RETURN c, o, d, cl, r
LIMIT 100"""
    return query

def view_individual_contract_graph(contract_id=None, contract_title=None):
    """
    View a single contract's graph structure
    Shows what nodes and relationships belong to this contract only
    """
    if not contract_id and not contract_title:
        print("❌ Please provide either contract_id or contract_title")
        return
    
    print("\n" + "="*80)
    print("📊 INDIVIDUAL CONTRACT GRAPH VIEW")
    print("="*80)
    
    # Try to reconnect if connection fails
    try:
        with neo4j_driver.session() as s:
            if contract_id:
                result = s.run("""
                    MATCH (c:Contract {id: $id})
                    OPTIONAL MATCH (c)<-[:IS_PARTY_TO]-(o:Organization)
                    OPTIONAL MATCH (c)-[:HAS_DATE]->(d:ImportantDate)
                    OPTIONAL MATCH (c)-[:HAS_CLAUSE]->(cl:Clause)
                    OPTIONAL MATCH (cl)-[:HAS_RISK]->(r:Risk)
                    OPTIONAL MATCH (cl)-[:HAS_REASON]->(rr:RiskReason)
                    OPTIONAL MATCH (cl)-[:HAS_OBLIGATION]->(ob:Obligation)
                    OPTIONAL MATCH (cl)-[:HAS_LIABILITY]->(li:Liability)
                    OPTIONAL MATCH (cl)-[:HAS_AI_SUMMARY]->(ai:AISummary)
                    RETURN c, 
                           collect(DISTINCT o) as parties,
                           collect(DISTINCT d) as dates,
                           collect(DISTINCT cl) as clauses,
                           collect(DISTINCT r) as risks
                """, id=contract_id)
            else:
                result = s.run("""
                    MATCH (c:Contract {title: $title})
                    OPTIONAL MATCH (c)<-[:IS_PARTY_TO]-(o:Organization)
                    OPTIONAL MATCH (c)-[:HAS_DATE]->(d:ImportantDate)
                    OPTIONAL MATCH (c)-[:HAS_CLAUSE]->(cl:Clause)
                    OPTIONAL MATCH (cl)-[:HAS_RISK]->(r:Risk)
                    OPTIONAL MATCH (cl)-[:HAS_REASON]->(rr:RiskReason)
                    OPTIONAL MATCH (cl)-[:HAS_OBLIGATION]->(ob:Obligation)
                    OPTIONAL MATCH (cl)-[:HAS_LIABILITY]->(li:Liability)
                    OPTIONAL MATCH (cl)-[:HAS_AI_SUMMARY]->(ai:AISummary)
                    RETURN c, 
                           collect(DISTINCT o) as parties,
                           collect(DISTINCT d) as dates,
                           collect(DISTINCT cl) as clauses,
                           collect(DISTINCT r) as risks
                """, title=contract_title)
        
        record = result.single()
        if record:
            c = record["c"]
            parties = [p for p in record["parties"] if p]
            dates = [d for d in record["dates"] if d]
            clauses = [cl for cl in record["clauses"] if cl]
            risks = [r for r in record["risks"] if r]
            
            print(f"\n📄 Contract: {c.get('title', 'Unknown')}")
            print(f"   ID: {c.get('id', 'N/A')[:30]}...")
            print(f"\n📊 Graph Statistics:")
            print(f"   Parties: {len(parties)}")
            print(f"   Dates: {len(dates)}")
            print(f"   Clauses: {len(clauses)}")
            print(f"   Risk Levels: {len(risks)}")
            
            print(f"\n🔗 Copy this query to Neo4j Browser to visualize:")
            print("-" * 80)
            query = get_contract_cypher_query(contract_id=contract_id, contract_title=contract_title)
            print(query)
            print("-" * 80)
            
            return {
                "contract": c,
                "parties": parties,
                "dates": dates,
                "clauses": clauses,
                "risks": risks,
                "cypher_query": query
            }
        else:
            print("❌ Contract not found")
            return None
            
    except Exception as e:
        print(f"❌ Neo4j connection failed: {e}")
        print("💡 Make sure:")
        print("   1. Your NEO4J_URI uses neo4j+ssc:// or neo4j+s://")
        print("   2. Username and password are correct")
        print("   3. Your Aura database is running")
        print("\n   Try running: reconnect_neo4j()")
        return None

def list_contracts_for_viewing():
    """
    List all contracts with their IDs and titles for easy selection
    """
    print("\n" + "="*80)
    print("📋 AVAILABLE CONTRACTS FOR VIEWING")
    print("="*80)
    
    # Try to reconnect if connection fails
    try:
        contracts = retrieve_all_contracts()
    except Exception as e:
        print(f"⚠️ Connection error: {e}")
        print("🔄 Attempting to reconnect...")
        if reconnect_neo4j():
            contracts = retrieve_all_contracts()
        else:
            print("❌ Could not connect to Neo4j. Please check your connection.")
            return []
    
    if not contracts:
        print("No contracts found in database")
        return []
    
    print(f"\nFound {len(contracts)} contract(s):\n")
    for i, contract in enumerate(contracts, 1):
        print(f"[{i}] {contract['title']}")
        print(f"    ID: {contract['id']}")
        print(f"    File: {contract['file_name']}\n")
    
    return contracts

print("✅ Individual contract graph viewing functions loaded!")
print("\nUsage:")
print("  1. reconnect_neo4j() - Reconnect if you get connection errors")
print("  2. list_contracts_for_viewing() - See all contracts")
print("  3. view_individual_contract_graph(contract_id='...') - View one contract")
print("  4. get_contract_cypher_query(contract_id='...') - Get Cypher query for Browser")
print("\n💡 If you get connection errors, run: reconnect_neo4j()")
# Out:
# ✅ Individual contract graph viewing functions loaded!
#
# Usage:
#   1. reconnect_neo4j() - Reconnect if you get connection errors
#   2. list_contracts_for_viewing() - See all contracts
#   3. view_individual_contract_graph(contract_id='...') - View one contract
#   4. get_contract_cypher_query(contract_id='...') - Get Cypher query for Browser
#
# 💡 If you get connection errors, run: reconnect_neo4j()

# %%
# ===== QUICK FIX: Reconnect Neo4j =====
# Run this cell if you get connection errors

# Close existing driver
try:
    neo4j_driver.close()
except:
    pass

# Re-initialize with URI fix
uri = os.environ["NEO4J_URI"]
if "neo4j+s://" in uri and "neo4j+ssc://" not in uri:
    uri = uri.replace("neo4j+s://", "neo4j+ssc://")
    print(f"🔄 Updated URI: {uri[:50]}...")

neo4j_driver = GraphDatabase.driver(
    uri,
    auth=(os.environ["NEO4J_USERNAME"], os.environ["NEO4J_PASSWORD"])
)

# Test connection
try:
    neo4j_driver.verify_connectivity()
    print("✅ Neo4j reconnected! Now try your query again.")
except Exception as e:
    print(f"❌ Connection failed: {e}")
    print("💡 Check your .env file and Neo4j Aura status")
# Out:
# 🔄 Updated URI: neo4j+ssc://8c5998b9.databases.neo4j.io...
# ✅ Neo4j reconnected! Now try your query again.

# %%
# ===== VECTOR SIMILARITY SEARCH EXAMPLE =====

print("\n\n" + "#"*80)
print("# VECTOR SIMILARITY SEARCH")
print("#"*80)

# Example searches
search_queries = [
    "payment terms and conditions",
    "liability and indemnification",
    "termination clause"
]

for query in search_queries:
    search_similar_clauses(query, top_k=3)
    print("\n" + "-"*80)
# Out:
# ################################################################################
# # VECTOR SIMILARITY SEARCH
# ################################################################################
#
# 🔍 Searching for clauses similar to: 'payment terms and conditions'
# ❌ Could not generate query embedding
#
# --------------------------------------------------------------------------------
#
# 🔍 Searching for clauses similar to: 'liability and indemnification'
# ❌ Could not generate query embedding
#
# --------------------------------------------------------------------------------
#
# 🔍 Searching for clauses similar to: 'termination clause'
# ❌ Could not generate query embedding
#
# --------------------------------------------------------------------------------

# %%
# ===== CLEANUP =====
import atexit
atexit.register(lambda: neo4j_driver.close())
print("🔒 Neo4j connection will close on exit")
# Out:
# 🔒 Neo4j connection will close on exit

# %%
# List all contracts to get IDs
list_contracts_for_viewing()
# Out:
# ================================================================================
# 📋 AVAILABLE CONTRACTS FOR VIEWING
# ================================================================================
#
# 📚 Retrieving all contracts...
# ✅ Found 3 contracts
#
# Found 3 contract(s):
#
# [1] Legal Services Agreement
#     ID: 1de79b4ffc94b68989ab72c79d929fc5169e8c48b1ea78fc7ee7c8bcd0b1c7d2
#     File: Legal-Services-Agreement.pdf
#
# [2] Unknown Contract
#     ID: 36b93039beb3de2504d3c21533f28516466e6f6ab2529f4bd31d275b66d27dd3
#     File: Employment_contract.pdf
#
# [3] Service Agreement
#     ID: cc92ad20222720eef7875a359d5d0c52166963bd678f7263c92a8cbd60726f80
#     File: sample_contract.pdf
# [{'id': '1de79b4ffc94b68989ab72c79d929fc5169e8c48b1ea78fc7ee7c8bcd0b1c7d2',
#   'title': 'Legal Services Agreement',
#   'file_name': 'Legal-Services-Agreement.pdf'},
#  {'id': '36b93039beb3de2504d3c21533f28516466e6f6ab2529f4bd31d275b66d27dd3',
#   'title': 'Unknown Contract',
#   'file_name': 'Employment_contract.pdf'},
#  {'id': 'cc92ad20222720eef7875a359d5d0c52166963bd678f7263c92a8cbd60726f80',
#   'title': 'Service Agreement',
#   'file_name': 'sample_contract.pdf'}]

# %%
# View individual contract and get the query
# Step 1: Get all contracts
contracts = list_contracts_for_viewing()

# Step 2: View the first contract individually
if contracts:
    print("\n" + "="*80)
    print("VIEWING FIRST CONTRACT")
    print("="*80)
    
    # Use the first contract's ID
    result = view_individual_contract_graph(contract_id=contracts[0]['id'])
    
    # The function will print a Cypher query - copy that to Neo4j Browser!
# Out:
# ================================================================================
# 📋 AVAILABLE CONTRACTS FOR VIEWING
# ================================================================================
#
# 📚 Retrieving all contracts...
# ✅ Found 3 contracts
#
# Found 3 contract(s):
#
# [1] Legal Services Agreement
#     ID: 1de79b4ffc94b68989ab72c79d929fc5169e8c48b1ea78fc7ee7c8bcd0b1c7d2
#     File: Legal-Services-Agreement.pdf
#
# [2] Unknown Contract
#     ID: 36b93039beb3de2504d3c21533f28516466e6f6ab2529f4bd31d275b66d27dd3
#     File: Employment_contract.pdf
#
# [3] Service Agreement
#     ID: cc92ad20222720eef7875a359d5d0c52166963bd678f7263c92a8cbd60726f80
#     File: sample_contract.pdf
#
#
# ================================================================================
# VIEWING FIRST CONTRACT
# ================================================================================
#
# ================================================================================
# 📊 INDIVIDUAL CONTRACT GRAPH VIEW
# ================================================================================
# ❌ Neo4j connection failed: The result has been consumed. Fetch all needed records before calling Result.consume().
# 💡 Make sure:
#    1. Your NEO4J_URI uses neo4j+ssc:// or neo4j+s://
#    2. Username and password are correct
#    3. Your Aura database is running
#
#    Try running: reconnect_neo4j()
